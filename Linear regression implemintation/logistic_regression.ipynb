# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.model_selection import train_test_split
from linear_model import LogisticRegression as my_model

# %%
data=pd.read_csv("exams.csv")
# data.describe()
# data.isnull().sum()
X=data[["score"]]
print(X.shape)
y=data["admission"]
model=my_model(iterations=1000,learning_rate=.1)
# Out:
# (113, 1)

# %%
plt.scatter(X,y)

# %%
scaler=MinMaxScaler()
X=scaler.fit_transform(X)
model.fit(X,y)
y_predicted=model.predict(X)
print(model.score(X,y))
plt.scatter(X,y)
X_range = np.linspace(0, 1, 100).reshape(-1,1)
plt.plot(X_range,model.predict_propapility(X_range))
# Out:
# 0.9557522123893806

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X,y)
model.score(X,y)
# Out:
# 0.9646017699115044

# %%
plt.scatter(X,y)
X_range = np.linspace(0, 1, 100).reshape(-1,1)
plt.plot(X_range,model.predict_proba(X_range))
# Out:
# [<matplotlib.lines.Line2D at 0x200f6db9b50>,
#  <matplotlib.lines.Line2D at 0x200f766d350>]
